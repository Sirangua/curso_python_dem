# %% [markdown]
# # Logica booleana
#
# ## Operadores lógicos
#
# - Igual que: a == b
# - No es igual: a != b
# - Menor que: a < b
# - Menor o igual que: a <= b
# - Mayor que: a > b
# - Mayor o igual que: a >= b

# %% [markdown]
# ## Sintaxis if
#
# ![image.png](attachment:image.png)

# %%
if prueba_logica:
    #sentencias a ejecutar
elif prueba_logica:
    #Sentencia a ejecutar
else:
    #Sentencia a ejecutar

# %% [markdown]
# ## Sintaxis else
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Sintaxis elif
#
# ![image.png](attachment:image.png)

# %%
a = 10
b = 5

if a != 10:
    print ("A es igual a 10")
elif b > 3:
    print ("B es mayor que 3")
else:
    print ("A es diferente de 10")
# Out:
# B es mayor que 3
